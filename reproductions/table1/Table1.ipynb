# %% [markdown]
# # EXPERIMENT 3 (Table 1)
#
# Reproducing Table 1: axiom satisfaction of three architectures (MLP, CNN, WEC) trained unsupervised on axiom losses, plus 16 known voting rules for comparison. IC sampling, 55 voters, 5 alternatives.
#
# Common hyperparameters (paper §5.1, §6.3):
# * 55 voters, 5 alternatives, IC sampling
# * 15,000 gradient steps, batch size 200, AdamW
# * Cosine annealing with warm restarts (T_0 = 100)
# * `sample_size_applicable = 400` for axiom checking
#
# Architecture-specific:
# * MLP: 4 hidden layers à 128. Optimizes NW, Anonymity, Condorcet, Pareto, Independence.
# * CNN: kernel1 = (5,1), kernel2 = (1,5), 64 channels, 3 linear layers à 128. Same axioms as MLP.
# * WEC: pretrained Word2Vec (corpus 100k, dim 200, window 7, skip-gram) + averaging + 3 linear layers à 128. Optimizes NW, Condorcet, Pareto only (anonymous by design).
#
# Decoding variants reported in Table 1: plain (`p`), neutrality-averaged (`n`), neutrality-and-anonymity-averaged (`na`). MLP/CNN report all three; WEC reports `p` and `n` only (anonymous by design).
#
# Paper run times (Fig. 16): MLP ≈ 5h 29min, CNN ≈ 6h 08min, WEC ≈ 2h 05min on a CPU laptop.

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import exp3
import utils
import plot_and_visual

MAX_NUM_VOTERS = 55
MAX_NUM_ALTERNATIVES = 5
ELECTION_SAMPLING = {'probmodel': 'IC'}
NUM_GRADIENT_STEPS = 15000
LOSS_REPORT_INTERVALS = 100
BATCH_SIZE = 200
LEARNING_SCHEDULER = 100
EVAL_DATASET_SIZE = 500
SAMPLE_SIZE_APPLICABLE = 400
SAMPLE_SIZE_MAXIMAL = int(1e6)
DISTANCE = 'KLD'

AXIOMS_CHECK_MODEL = ['Anonymity', 'Neutrality', 'Condorcet', 'Pareto', 'Independence']

AXIOM_OPT_MLP_CNN = {
    'No_winner':   {'weight': 10, 'period': 'always'},
    'All_winners': None,
    'Inadmissible': None,
    'Resoluteness': None,
    'Parity':      None,
    'Anonymity':   {'weight': 1, 'period': 'always', 'sample': 50},
    'Neutrality':  None,
    'Condorcet1':  {'weight': 2, 'period': 'always'},
    'Condorcet2':  None,
    'Pareto1':     None,
    'Pareto2':     {'weight': 1, 'period': 'always'},
    'Independence':{'weight': 1, 'period': 'always', 'sample': 4},
}

AXIOM_OPT_WEC = {
    'No_winner':   {'weight': 10, 'period': 'always'},
    'All_winners': None,
    'Inadmissible': None,
    'Resoluteness': None,
    'Parity':      None,
    'Anonymity':   None,
    'Neutrality':  None,
    'Condorcet1':  {'weight': 2, 'period': 'always'},
    'Condorcet2':  None,
    'Pareto1':     None,
    'Pareto2':     {'weight': 1, 'period': 'always'},
    'Independence':None,
}

# %%
print('Training MLP (NW, A, C, P, I)')
location_mlp = exp3.experiment3(
    architecture = 'MLP',
    max_num_voters = MAX_NUM_VOTERS,
    max_num_alternatives = MAX_NUM_ALTERNATIVES,
    election_sampling = ELECTION_SAMPLING,
    num_gradient_steps = NUM_GRADIENT_STEPS,
    report_intervals = NUM_GRADIENT_STEPS,
    eval_dataset_size = EVAL_DATASET_SIZE,
    model_to_rule = {
        'plain': True,
        'neut-averaged': None,
        'neut-anon-averaged': [12, 10],
    },
    sample_size_applicable = SAMPLE_SIZE_APPLICABLE,
    sample_size_maximal = SAMPLE_SIZE_MAXIMAL,
    architecture_parameters = None,
    axioms_check_model = AXIOMS_CHECK_MODEL,
    axioms_check_rule = [],
    axiom_opt = AXIOM_OPT_MLP_CNN,
    comp_rules_axioms = [],
    comp_rules_similarity = [],
    distance = DISTANCE,
    batch_size = BATCH_SIZE,
    learning_scheduler = LEARNING_SCHEDULER,
)
print(f'MLP results: {location_mlp}')

# %%
print('Training CNN (NW, A, C, P, I)')
location_cnn = exp3.experiment3(
    architecture = 'CNN',
    max_num_voters = MAX_NUM_VOTERS,
    max_num_alternatives = MAX_NUM_ALTERNATIVES,
    election_sampling = ELECTION_SAMPLING,
    num_gradient_steps = NUM_GRADIENT_STEPS,
    report_intervals = NUM_GRADIENT_STEPS,
    loss_report_intervals=LOSS_REPORT_INTERVALS,
    eval_dataset_size = EVAL_DATASET_SIZE,
    model_to_rule = {
        'plain': True,
        'neut-averaged': None,
        'neut-anon-averaged': [12, 10],
    },
    sample_size_applicable = SAMPLE_SIZE_APPLICABLE,
    sample_size_maximal = SAMPLE_SIZE_MAXIMAL,
    architecture_parameters = {
        'kernel1': [5, 1],
        'kernel2': [1, 5],
        'channels': 64,
    },
    axioms_check_model = AXIOMS_CHECK_MODEL,
    axioms_check_rule = [],
    axiom_opt = AXIOM_OPT_MLP_CNN,
    comp_rules_axioms = [],
    comp_rules_similarity = [],
    distance = DISTANCE,
    batch_size = BATCH_SIZE,
    learning_scheduler = LEARNING_SCHEDULER,
)
print(f'CNN results: {location_cnn}')
# Out:
# Training CNN (NW, A, C, P, I)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 print('Training CNN (NW, A, C, P, I)')
# ----> 2 location_cnn = exp3.experiment3(
#       3     architecture = 'CNN',
#       4     max_num_voters = MAX_NUM_VOTERS,
#       5     max_num_alternatives = MAX_NUM_ALTERNATIVES,
#       6     election_sampling = ELECTION_SAMPLING,
#       7     num_gradient_steps = NUM_GRADIENT_STEPS,
#       8     report_intervals = NUM_GRADIENT_STEPS,
#       9     loss_report_intervals=LOSS_REPORT_INTERVALS,
#      10     eval_dataset_size = EVAL_DATASET_SIZE,
#      11     model_to_rule = {
#      12         'plain': True,
#      13         'neut-averaged': None,
#      14         'neut-anon-averaged': [12, 10],
#      15     },
#      16     sample_size_applicable = SAMPLE_SIZE_APPLICABLE,
#      17     sample_size_maximal = SAMPLE_SIZE_MAXIMAL,
#      18     architecture_parameters = {
#      19         'kernel1': [5, 1],
#      20         'kernel2': [1, 5],
#      21         'channels': 64,
#      22     },
#      23     axioms_check_model = AXIOMS_CHECK_MODEL,
#      24     axioms_check_rule = [],
#      25     axiom_opt = AXIOM_OPT_MLP_CNN,
#      26     comp_rules_axioms = [],
#      27     comp_rules_similarity = [],
#      28     distance = DISTANCE,
#      29     batch_size = BATCH_SIZE,
#      30     learning_scheduler = LEARNING_SCHEDULER,
#      31 )
#      32 print(f'CNN results: {location_cnn}')
#
# File ~/code/AxiomaticDeepVoting/exp3.py:264, in experiment3(architecture, max_num_voters, max_num_alternatives, election_sampling, num_gradient_steps, report_intervals, eval_dataset_size, model_to_rule, sample_size_applicable, sample_size_maximal, architecture_parameters, axioms_check_model, axioms_check_rule, axiom_opt, comp_rules_axioms, comp_rules_similarity, distance, random_seed, batch_size, learning_rate, learning_scheduler, weight_decay, loss_report_intervals, save_model, load_model_from)
#     262 current_time = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
#     263 location = f"./results/exp3/{architecture}/exp3_{current_time}_{prob_model}"
# --> 264 os.mkdir(location)
#     265 print(f'Saving location: {location}')
#     268 results = {
#     269     "location": location,
#     270     "architecture": architecture,
#    (...)
#     294     "load_model_from": load_model_from,
#     295 }
#
# FileNotFoundError: [Errno 2] No such file or directory: './results/exp3/CNN/exp3_2026-05-14_22-10-24_IC'

# %%
print('Training WEC (NW, C, P)')
import exp3
location_wec = exp3.experiment3(
    architecture = 'WEC',
    max_num_voters = MAX_NUM_VOTERS,
    max_num_alternatives = MAX_NUM_ALTERNATIVES,
    election_sampling = ELECTION_SAMPLING,
    num_gradient_steps = NUM_GRADIENT_STEPS,
    # report_intervals = NUM_GRADIENT_STEPS // 5, # these are more like eval_intervals
    report_intervals = NUM_GRADIENT_STEPS, # these are more like eval_intervals
    loss_report_intervals=LOSS_REPORT_INTERVALS,
    eval_dataset_size = EVAL_DATASET_SIZE,
    model_to_rule = {
        'plain': True,
        'neut-averaged': None,
        'neut-anon-averaged': False,
    },
    sample_size_applicable = SAMPLE_SIZE_APPLICABLE,
    sample_size_maximal = SAMPLE_SIZE_MAXIMAL,
    architecture_parameters = {
        'we_corpus_size': int(1e5),
        'we_size': 200,
        'we_window': 7,
        'we_algorithm': 1,
    },
    axioms_check_model = AXIOMS_CHECK_MODEL,
    axioms_check_rule = [],
    axiom_opt = AXIOM_OPT_WEC,
    comp_rules_axioms = [],
    comp_rules_similarity = [],
    distance = DISTANCE,
    batch_size = BATCH_SIZE,
    learning_scheduler = LEARNING_SCHEDULER,
    save_model=True,
    output_dir="/Users/felixwu/code/AxiomaticDeepVoting/results/",
)
print(f'WEC results: {location_wec}')
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /Users/felixwu/.netrc.
# Training WEC (NW, C, P)
# Saving location: /Users/felixwu/code/AxiomaticDeepVoting/results/exp3/WEC/exp3_2026-05-14_22-13-38_IC
# wandb: Currently logged in as: felix_wu (felix_wu-technische-universit-t-m-nchen) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.27.0
# Run data is saved locally in <code>/Users/felixwu/code/AxiomaticDeepVoting/reproductions/table1/wandb/run-20260514_221338-7z3n4glj</code>
# Syncing run <strong><a href='https://wandb.ai/felix_wu-technische-universit-t-m-nchen/AxiomaticDeepVoting/runs/7z3n4glj' target="_blank">exp3_2026-05-14_22-13-38_IC</a></strong> to <a href='https://wandb.ai/felix_wu-technische-universit-t-m-nchen/AxiomaticDeepVoting' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/felix_wu-technische-universit-t-m-nchen/AxiomaticDeepVoting' target="_blank">https://wandb.ai/felix_wu-technische-universit-t-m-nchen/AxiomaticDeepVoting</a>
#  View run at <a href='https://wandb.ai/felix_wu-technische-universit-t-m-nchen/AxiomaticDeepVoting/runs/7z3n4glj' target="_blank">https://wandb.ai/felix_wu-technische-universit-t-m-nchen/AxiomaticDeepVoting/runs/7z3n4glj</a>
# Now pretraining word embeddings
# First generate profiles and turn them into corpus
# Now train word embeddings
# Done pretraining word embeddings.
# Save the word embeddings.
# Now generate dev and test profiles
# Now starting to train
#   9%|▊         | 1312/15000 [02:32<26:26,  8.63it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 print('Training WEC (NW, C, P)')
#       2 import exp3
# ----> 3 location_wec = exp3.experiment3(
#       4     architecture = 'WEC',
#       5     max_num_voters = MAX_NUM_VOTERS,
#       6     max_num_alternatives = MAX_NUM_ALTERNATIVES,
#       7     election_sampling = ELECTION_SAMPLING,
#       8     num_gradient_steps = NUM_GRADIENT_STEPS,
#       9     # report_intervals = NUM_GRADIENT_STEPS // 5, # these are more like eval_intervals
#      10     report_intervals = NUM_GRADIENT_STEPS, # these are more like eval_intervals
#      11     loss_report_intervals=LOSS_REPORT_INTERVALS,
#      12     eval_dataset_size = EVAL_DATASET_SIZE,
#      13     model_to_rule = {
#      14         'plain': True,
#      15         'neut-averaged': None,
#      16         'neut-anon-averaged': False,
#      17     },
#      18     sample_size_applicable = SAMPLE_SIZE_APPLICABLE,
#      19     sample_size_maximal = SAMPLE_SIZE_MAXIMAL,
#      20     architecture_parameters = {
#      21         'we_corpus_size': int(1e5),
#      22         'we_size': 200,
#      23         'we_window': 7,
#      24         'we_algorithm': 1,
#      25     },
#      26     axioms_check_model = AXIOMS_CHECK_MODEL,
#      27     axioms_check_rule = [],
#      28     axiom_opt = AXIOM_OPT_WEC,
#      29     comp_rules_axioms = [],
#      30     comp_rules_similarity = [],
#      31     distance = DISTANCE,
#      32     batch_size = BATCH_SIZE,
#      33     learning_scheduler = LEARNING_SCHEDULER,
#      34     save_model=True,
#      35     output_dir="/Users/felixwu/code/AxiomaticDeepVoting/results/",
#      36 )
#      37 print(f'WEC results: {location_wec}')
#
# File ~/code/AxiomaticDeepVoting/exp3.py:532, in experiment3(architecture, max_num_voters, max_num_alternatives, election_sampling, num_gradient_steps, report_intervals, eval_dataset_size, model_to_rule, sample_size_applicable, sample_size_maximal, architecture_parameters, axioms_check_model, axioms_check_rule, axiom_opt, comp_rules_axioms, comp_rules_similarity, output_dir, distance, random_seed, batch_size, learning_rate, learning_scheduler, weight_decay, loss_report_intervals, save_model, load_model_from)
#     530 exp_optimizer.zero_grad()
#     531 loss.backward()
# --> 532 exp_optimizer.step()
#     534 if learning_scheduler is not None:
#     535     scheduler.step()
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/torch/optim/lr_scheduler.py:137, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     135 opt = opt_ref()
#     136 opt._opt_called = True  # type: ignore[union-attr]
# --> 137 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/torch/optim/optimizer.py:487, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     482         else:
#     483             raise RuntimeError(
#     484                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     485             )
# --> 487 out = func(*args, **kwargs)
#     488 self._optimizer_step_code()
#     490 # call optimizer step post hooks
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/torch/optim/optimizer.py:91, in _use_grad_for_differentiable.<locals>._use_grad(self, *args, **kwargs)
#      89     torch.set_grad_enabled(self.defaults["differentiable"])
#      90     torch._dynamo.graph_break()
# ---> 91     ret = func(self, *args, **kwargs)
#      92 finally:
#      93     torch._dynamo.graph_break()
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/torch/optim/adamw.py:220, in AdamW.step(self, closure)
#     207     beta1, beta2 = cast(Tuple[float, float], group["betas"])
#     209     has_complex = self._init_group(
#     210         group,
#     211         params_with_grad,
#    (...)
#     217         state_steps,
#     218     )
# --> 220     adamw(
#     221         params_with_grad,
#     222         grads,
#     223         exp_avgs,
#     224         exp_avg_sqs,
#     225         max_exp_avg_sqs,
#     226         state_steps,
#     227         amsgrad=amsgrad,
#     228         beta1=beta1,
#     229         beta2=beta2,
#     230         lr=group["lr"],
#     231         weight_decay=group["weight_decay"],
#     232         eps=group["eps"],
#     233         maximize=group["maximize"],
#     234         foreach=group["foreach"],
#     235         capturable=group["capturable"],
#     236         differentiable=group["differentiable"],
#     237         fused=group["fused"],
#     238         grad_scale=getattr(self, "grad_scale", None),
#     239         found_inf=getattr(self, "found_inf", None),
#     240         has_complex=has_complex,
#     241     )
#     243 return loss
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/torch/optim/optimizer.py:154, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     152     return disabled_func(*args, **kwargs)
#     153 else:
# --> 154     return func(*args, **kwargs)
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/torch/optim/adamw.py:782, in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     779 else:
#     780     func = _single_tensor_adamw
# --> 782 func(
#     783     params,
#     784     grads,
#     785     exp_avgs,
#     786     exp_avg_sqs,
#     787     max_exp_avg_sqs,
#     788     state_steps,
#     789     amsgrad=amsgrad,
#     790     beta1=beta1,
#     791     beta2=beta2,
#     792     lr=lr,
#     793     weight_decay=weight_decay,
#     794     eps=eps,
#     795     maximize=maximize,
#     796     capturable=capturable,
#     797     differentiable=differentiable,
#     798     grad_scale=grad_scale,
#     799     found_inf=found_inf,
#     800     has_complex=has_complex,
#     801 )
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/torch/optim/adamw.py:427, in _single_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     425         denom = (max_exp_avg_sqs[i].sqrt() / bias_correction2_sqrt).add_(eps)
#     426     else:
# --> 427         denom = (exp_avg_sq.sqrt() / bias_correction2_sqrt).add_(eps)
#     429     param.addcdiv_(exp_avg, denom, value=-step_size)
#     431 # Lastly, switch back to complex view
#
# KeyboardInterrupt:
# Error in callback <bound method _WandbInit._post_run_cell_hook of <wandb.sdk.wandb_init._WandbInit object at 0x108331240>> (for post_run_cell), with arguments args (<ExecutionResult object at 15ef63a00, execution_count=2 error_before_exec=None error_in_exec= info=<ExecutionInfo object at 15ef62d40, raw_cell="print('Training WEC (NW, C, P)')
# import exp3
# locat.." store_history=True silent=False shell_futures=True cell_id=vscode-notebook-cell:/Users/felixwu/code/AxiomaticDeepVoting/reproductions/table1/Table1.ipynb#W4sZmlsZQ%3D%3D> result=None>,),kwargs {}:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/wandb_init.py:613, in _WandbInit._post_run_cell_hook(self, *args, **kwargs)
#     610     return
#     612 self._logger.info("resuming backend")
# --> 613 self._interface.publish_resume()
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/interface/interface.py:830, in InterfaceBase.publish_resume(self)
#     828 def publish_resume(self) -> None:
#     829     resume = pb.ResumeRequest()
# --> 830     self._publish_resume(resume)
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/interface/interface_shared.py:338, in InterfaceShared._publish_resume(self, resume)
#     336 def _publish_resume(self, resume: pb.ResumeRequest) -> None:
#     337     rec = self._make_request(resume=resume)
# --> 338     self._publish(rec)
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/interface/interface_sock.py:46, in InterfaceSock._publish(self, record, nowait)
#      44     self._asyncer.run_soon(lambda: self._client.publish(request))
#      45 else:
# ---> 46     self._asyncer.run(lambda: self._client.publish(request))
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/lib/asyncio_manager.py:137, in AsyncioManager.run(self, fn)
#     134 future = self._schedule(fn, daemon=False)
#     136 try:
# --> 137     return future.result()
#     139 except concurrent.futures.CancelledError:
#     140     raise RunCancelledError from None
#
# File ~/.local/share/uv/python/cpython-3.10.19-macos-aarch64-none/lib/python3.10/concurrent/futures/_base.py:458, in Future.result(self, timeout)
#     456     raise CancelledError()
#     457 elif self._state == FINISHED:
# --> 458     return self.__get_result()
#     459 else:
#     460     raise TimeoutError()
#
# File ~/.local/share/uv/python/cpython-3.10.19-macos-aarch64-none/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/lib/asyncio_manager.py:223, in AsyncioManager._wrap(self, fn, daemon, name)
#     220     if name and (task := asyncio.current_task()):
#     221         task.set_name(name)
# --> 223     return await fn()
#     224 finally:
#     225     if not daemon:
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/lib/service/service_client.py:42, in ServiceClient.publish(self, request)
#      40 async def publish(self, request: spb.ServerRequest) -> None:
#      41     """Send a request without waiting for a response."""
# ---> 42     await self._send_server_request(request)
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/lib/service/service_client.py:84, in ServiceClient._send_server_request(self, request)
#      81 self._writer.write(data)
#      83 try:
# ---> 84     await self._drain_writer()
#      85 except Exception as e:
#      86     self._broken_exc = e
#
# File ~/code/AxiomaticDeepVoting/.venv/lib/python3.10/site-packages/wandb/sdk/lib/service/service_client.py:92, in ServiceClient._drain_writer(self)
#      90 async def _drain_writer(self) -> None:
#      91     """Wait for the socket's flow control."""
# ---> 92     await self._writer.drain()
#
# File ~/.local/share/uv/python/cpython-3.10.19-macos-aarch64-none/lib/python3.10/asyncio/streams.py:371, in StreamWriter.drain(self)
#     360 if self._transport.is_closing():
#     361     # Wait for protocol.connection_lost() call
#     362     # Raise connection closing error if any,
#    (...)
#     368     # in a loop would never call connection_lost(), so it
#     369     # would not see an error when the socket is closed.
#     370     await sleep(0)
# --> 371 await self._protocol._drain_helper()
#
# File ~/.local/share/uv/python/cpython-3.10.19-macos-aarch64-none/lib/python3.10/asyncio/streams.py:167, in FlowControlMixin._drain_helper(self)
#     165 async def _drain_helper(self):
#     166     if self._connection_lost:
# --> 167         raise ConnectionResetError('Connection lost')
#     168     if not self._paused:
#     169         return
#
# ConnectionResetError: Connection lost

# %%
print('Computing axiom satisfaction of the 16 comparison rules')
location_rules = exp3.experiment3(
    architecture = 'MLP',
    max_num_voters = MAX_NUM_VOTERS,
    max_num_alternatives = MAX_NUM_ALTERNATIVES,
    election_sampling = ELECTION_SAMPLING,
    num_gradient_steps = 0,
    report_intervals = 1,
    eval_dataset_size = EVAL_DATASET_SIZE,
    model_to_rule = {
        'plain': False,
        'neut-averaged': False,
        'neut-anon-averaged': False,
    },
    sample_size_applicable = SAMPLE_SIZE_APPLICABLE,
    sample_size_maximal = SAMPLE_SIZE_MAXIMAL,
    architecture_parameters = None,
    axioms_check_model = [],
    axioms_check_rule = list(utils.dict_axioms_rules.keys()),
    axiom_opt = {
        'No_winner': None,
        'All_winners': None,
        'Inadmissible': None,
        'Resoluteness': None,
        'Parity': None,
        'Anonymity': None,
        'Neutrality': None,
        'Condorcet1': None,
        'Condorcet2': None,
        'Pareto1': None,
        'Pareto2': None,
        'Independence': None,
    },
    comp_rules_axioms = list(utils.dict_rules_all_fast.keys()),
    comp_rules_similarity = [],
)
print(f'Rule baseline results: {location_rules}')

# %%
plot_and_visual.exp3_table(
    file_rules = 'results/exp3/MLP/exp3_2026-05-10_18-24-53_IC',
    file_MLP   = 'results/exp3/MLP/exp3_2026-05-05_11-04-57_IC',
    file_CNN   = 'results/exp3/CNN/exp3_2026-05-10_18-53-58_IC',
    file_WEC   = 'results/exp3/WEC/exp3_2026-05-10_19-05-20_IC',
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_and_visual.exp3_table(
#       2     file_rules = 'results/exp3/MLP/exp3_2026-05-10_18-24-53_IC',
#       3     file_MLP   = 'results/exp3/MLP/exp3_2026-05-05_11-04-57_IC',
#       4     file_CNN   = 'results/exp3/CNN/exp3_2026-05-10_18-33-57_IC',
#       5     file_WEC   = 'results/exp3/WEC/exp3_2026-05-10_19-05-20_IC',
#       6 )
#
# File ~/code/AxiomaticDeepVoting/plot_and_visual.py:1032, in exp3_table(file_rules, file_MLP, file_CNN, file_WEC)
#    1028     exp_data = json.load(json_file)
#    1030 # Plain axiom satisfaction
#    1031 axiom_sat_plain = [
# -> 1032     exp_data["axiom_satisfaction"]["model_plain"]["Anonymity"]["cond_satisfaction"],
#    1033     exp_data["axiom_satisfaction"]["model_plain"]["Neutrality"]["cond_satisfaction"],
#    1034     exp_data["axiom_satisfaction"]["model_plain"]["Condorcet"]["cond_satisfaction"],
#    1035     exp_data["axiom_satisfaction"]["model_plain"]["Pareto"]["cond_satisfaction"],
#    1036     exp_data["axiom_satisfaction"]["model_plain"]["Independence"]["cond_satisfaction"],
#    1037 ]
#    1038 axiom_sat_plain.append(sum(axiom_sat_plain)/len(axiom_sat_plain))
#    1039 axiom_sat_plain = [round(100*itm, 1) for itm in axiom_sat_plain]
#
# KeyError: 'axiom_satisfaction'
