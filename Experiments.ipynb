# %%
import exp1
import plot_and_visual

file_locations = {}
for rule_name in ['Plurality', 'Borda', 'Copeland']:
    print(f'Next: MLP with IC and rule {rule_name}') 
    location = exp1.experiment1(
        architecture = 'MLP',
        rule_names = [rule_name],
        max_num_voters = 10,
        max_num_alternatives = 3,
        election_sampling = {'probmodel':'IC'},
        num_gradient_steps = int(200),
        eval_dataset_size = int(500),
        sample_size_applicable = 100,
        sample_size_maximal = int(1e6),
        comparison_rules = ['Plurality', 'Borda', 'Copeland'],
    )
    file_locations[rule_name] = location

plot_and_visual.plot_exp1(
    file_plurality = file_locations['Plurality'],
    file_borda = file_locations['Borda'],
    file_copeland = file_locations['Copeland'],
)
# Out:
# Next: MLP with IC and rule Plurality
# Saving location: ./results/exp1/MLP/exp1_2026-01-09_00-48-54_Plurality_IC
# Now generate dev and test data
# Now starting to train
#  11%|████████▎                                                                   | 22/200 [00:00<00:01, 113.78it/s]
# Step 0: dev-loss 0.68092, dev-accuracy 0.562, lr=0.001
# 100%|███████████████████████████████████████████████████████████████████████████| 200/200 [00:01<00:00, 141.91it/s]
# Done training. Test-accuracy: 0.982
# Number of parameters of the model: 28547
# Admissability:
#     no_winner_at_all 0.0
#     no_admissible_winner 0.0
#     all_admissible_winner 0.4
#     some_inadmissible_winner 0.0
# The model satisfies axiom Anonymity to 89.0%
# The model satisfies axiom Weak anonymity to 98.0%
# The model satisfies axiom Neutrality to 91.0%
# The model satisfies axiom Weak neutrality to 99.0%
# The model satisfies axiom Condorcet to 96.0%
# The model satisfies axiom Pareto to 100.0%
# The model satisfies axiom Independence to 70.0%
# Rule Plurality satisfies axiom Condorcet to 98.0%
# Rule Plurality satisfies axiom Independence to 68.0%
# The learned rule coincides with the Plurality rule in 98.2% of the sampled cases
# The learned rule coincides with the Borda rule in 89.8% of the sampled cases
# The learned rule coincides with the Copeland rule in 91.0% of the sampled cases
# Runtime (in min): 0
# Next: MLP with IC and rule Borda
# Saving location: ./results/exp1/MLP/exp1_2026-01-09_00-49-03_Borda_IC
# Now generate dev and test data
# Now starting to train
#   8%|█▎                | 15/200 [00:00<00:01, 144.36it/s]
# Step 0: dev-loss 0.67636, dev-accuracy 0.554, lr=0.001
# 100%|█████████████████| 200/200 [00:01<00:00, 148.09it/s]
# Done training. Test-accuracy: 0.962
# Number of parameters of the model: 28547
# Admissability:
#     no_winner_at_all 0.0
#     no_admissible_winner 0.0
#     all_admissible_winner 0.394
#     some_inadmissible_winner 0.0
# The model satisfies axiom Anonymity to 89.0%
# The model satisfies axiom Weak anonymity to 99.0%
# The model satisfies axiom Neutrality to 94.0%
# The model satisfies axiom Weak neutrality to 98.0%
# The model satisfies axiom Condorcet to 97.0%
# The model satisfies axiom Pareto to 100.0%
# The model satisfies axiom Independence to 65.0%
# Rule Borda satisfies axiom Condorcet to 96.0%
# Rule Borda satisfies axiom Independence to 57.99999999999999%
# The learned rule coincides with the Plurality rule in 90.8% of the sampled cases
# The learned rule coincides with the Borda rule in 96.2% of the sampled cases
# The learned rule coincides with the Copeland rule in 94.39999999999999% of the sampled cases
# Runtime (in min): 0
# Next: MLP with IC and rule Copeland
# Saving location: ./results/exp1/MLP/exp1_2026-01-09_00-49-09_Copeland_IC
# Now generate dev and test data
# Now starting to train
#  12%|██                | 23/200 [00:00<00:01, 119.34it/s]
# Step 0: dev-loss 0.69379, dev-accuracy 0.01, lr=0.001
# 100%|█████████████████| 200/200 [00:01<00:00, 147.73it/s]
# Done training. Test-accuracy: 0.934
# Number of parameters of the model: 28547
# Admissability:
#     no_winner_at_all 0.0
#     no_admissible_winner 0.0
#     all_admissible_winner 0.358
#     some_inadmissible_winner 0.0
# The model satisfies axiom Anonymity to 90.0%
# The model satisfies axiom Weak anonymity to 100.0%
# The model satisfies axiom Neutrality to 79.0%
# The model satisfies axiom Weak neutrality to 98.0%
# The model satisfies axiom Condorcet to 93.0%
# The model satisfies axiom Pareto to 100.0%
# The model satisfies axiom Independence to 62.0%
# Rule Copeland satisfies axiom Condorcet to 100.0%
# Rule Copeland satisfies axiom Independence to 63.0%
# The learned rule coincides with the Plurality rule in 92.0% of the sampled cases
# The learned rule coincides with the Borda rule in 93.4% of the sampled cases
# The learned rule coincides with the Copeland rule in 93.4% of the sampled cases
# Runtime (in min): 0
